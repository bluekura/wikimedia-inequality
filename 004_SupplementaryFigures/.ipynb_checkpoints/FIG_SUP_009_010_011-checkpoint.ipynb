# %%
# %matplotlib inline  
import glob
import zipfile
#import multiprocessing as mp
import gc
#from collections import defaultdict
import csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
import numpy as np
from sklearn import manifold, datasets, mixture

# %%
final_table = pd.read_csv("./data/Allwiki_output_modify_langinfo.txt", index_col=0)

# %%
final_table[:10]

# %%
var =  '3:Num_Edit'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $N_e$ for wiki, wiktionary, wikibooks")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(N_e)$ for wiki, wiktionary, wikibooks")
plt.show()

var =  '4:Num_Editor'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $N_p$ for wiki, wiktionary, wikibooks")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(N_p)$ for wiki, wiktionary, wikibooks")
plt.show()

var =  '6:Num_Article'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $N_a$ for wiki, wiktionary, wikibooks")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(N_a)$ for wiki, wiktionary, wikibooks")
plt.show()

var =  '7:Wiki_Size'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $S$ for wiki, wiktionary, wikibooks")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(S)$ for wiki, wiktionary, wikibooks")
plt.show()

# %%
var = '3:Num_Edit'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $N_e$ for wiki, wiktionary, wikibooks, wikiquote")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(N_e)$ for wiki, wiktionary, wikibooks, wikiquote")
plt.show()

var = '4:Num_Editor'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $N_p$ for wiki, wiktionary, wikibooks, wikiquote")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(N_p)$ for wiki, wiktionary, wikibooks, wikiquote")
plt.show()

var = '6:Num_Article'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $N_a$ for wiki, wiktionary, wikibooks, wikiquote")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(N_a)$ for wiki, wiktionary, wikibooks, wikiquote")
plt.show()

var = '7:Wiki_Size'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
#print X
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $S$ for wiki, wiktionary, wikibooks, wikiquote")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(S)$ for wiki, wiktionary, wikibooks, wikiquote")
plt.show()

# %%
var = '3:Num_Edit'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $N_e$ for wiki, wiktionary, wikibooks, wikiquote, wikisource")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(N_e)$ for wiki, wiktionary, wikibooks, wikiquote, wikisource")
plt.show()

var = '4:Num_Editor'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $N_p$ for wiki, wiktionary, wikibooks, wikiquote, wikisource")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(N_p)$ for wiki, wiktionary, wikibooks, wikiquote, wikisource")
plt.show()

var = '6:Num_Article'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $N_a$ for wiki, wiktionary, wikibooks, wikiquote, wikisource")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(N_a)$ for wiki, wiktionary, wikibooks, wikiquote, wikisource")
plt.show()

var = '7:Wiki_Size'
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")

X = (np.array(temp_table))
#print X
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title("T-SNE $S$ for wiki, wiktionary, wikibooks, wikiquote, wikisource")
plt.show()

X = np.log(np.array(temp_table))
#X = (np.array(temp_table))
n_components = 2
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=0)
Y = tsne.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1])
plt.title ("T-SNE $log(S)$ for wiki, wiktionary, wikibooks, wikiquote, wikisource")
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

var = '3:Num_Edit'
ax = axes[0]
ax.set_xlabel("t-SNE $N_e$")
dim = 3
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
#temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
#temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
#temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
#temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")
temp_table.columns = ["X1", "X2", "X3", "X4", "X5"][0:dim]
#X = np.log(np.array(temp_table))
X = (np.array(temp_table))
dpgmm = mixture.BayesianGaussianMixture(
    n_components=10, covariance_type='full', weight_concentration_prior=1e-2,
    weight_concentration_prior_type='dirichlet_process',
    mean_precision_prior=0.01, covariance_prior=1e0 * np.eye(dim),
    init_params="random", max_iter=100, random_state=2).fit(X)

n_components = 2
cluster = []
for i in temp_table.iterrows():
    cluster.append(dpgmm.predict(i[1:])[0])
map = {}
for i, j in enumerate(set(cluster)):
    map[j] = i
for i in range(len(cluster)):
    cluster[i] = map[cluster[i]]
    
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=2)
Y = tsne.fit_transform(X)
Y = np.concatenate((Y, (np.array([cluster])).T), axis=1)
ax.scatter(Y[:, 0], Y[:, 1], c=Y[:, 2], alpha = 0.9)


var = '4:Num_Editor'
ax = axes[1]
ax.set_xlabel("t-SNE $N_p$")
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
#temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
#temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
#temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
#temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")
temp_table.columns = ["X1", "X2", "X3", "X4", "X5"][0:dim]
#X = np.log(np.array(temp_table))
X = (np.array(temp_table))
dpgmm = mixture.BayesianGaussianMixture(
    n_components=10, covariance_type='full', weight_concentration_prior=1,
    weight_concentration_prior_type='dirichlet_process',
    mean_precision_prior=0.01, covariance_prior=1e0 * np.eye(dim),
    init_params="random", max_iter=100, random_state=2).fit(X)

n_components = 2
cluster = []
for i in temp_table.iterrows():
    cluster.append(dpgmm.predict(i[1:])[0])
map = {}
for i, j in enumerate(set(cluster)):
    map[j] = i
for i in range(len(cluster)):
    cluster[i] = map[cluster[i]]
    
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=2)
Y = tsne.fit_transform(X)
Y = np.concatenate((Y, (np.array([cluster])).T), axis=1)
ax.scatter(Y[:, 0], Y[:, 1], c=Y[:, 2], alpha = 0.9)

var = '6:Num_Article'
ax = axes[2]
ax.set_xlabel("t-SNE $N_a$")
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
#temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
#temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
#temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
#temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")
temp_table.columns = ["X1", "X2", "X3", "X4", "X5"][0:dim]
#X = np.log(np.array(temp_table))
X = (np.array(temp_table))
dpgmm = mixture.BayesianGaussianMixture(
    n_components=10, covariance_type='full', weight_concentration_prior=1,
    weight_concentration_prior_type='dirichlet_process',
    mean_precision_prior=0.01, covariance_prior=1e0 * np.eye(dim),
    init_params="random", max_iter=100, random_state=2).fit(X)

n_components = 2
cluster = []
for i in temp_table.iterrows():
    cluster.append(dpgmm.predict(i[1:])[0])
map = {}
for i, j in enumerate(set(cluster)):
    map[j] = i
for i in range(len(cluster)):
    cluster[i] = map[cluster[i]]
    
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=5)
Y = tsne.fit_transform(X)
Y = np.concatenate((Y, (np.array([cluster])).T), axis=1)
ax.scatter(Y[:, 0], Y[:, 1], c=Y[:, 2], alpha = 0.9)

index = 0
labellist = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j", "k", "l", "m"]
for ax in fig.get_axes():
    ax.get_yaxis().set_label_coords(-0.1,0.5)
    ax.yaxis.label.set_fontsize(14)
    ax.tick_params(axis='x', labelsize=14)

    ax.text(0.2, 0.9, labellist[index], fontsize=14, weight='bold', transform=ax.transAxes)
    index += 1

plt.tight_layout()
plt.savefig('SUP_FIG_009.pdf')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

var = '3:Num_Edit'
ax = axes[0]
ax.set_xlabel("t-SNE $N_e$")
dim = 4
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
#temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
#temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")
temp_table.columns = ["X1", "X2", "X3", "X4", "X5"][0:dim]
#X = np.log(np.array(temp_table))
X = (np.array(temp_table))
dpgmm = mixture.BayesianGaussianMixture(
    n_components=10, covariance_type='full', weight_concentration_prior=1e-2,
    weight_concentration_prior_type='dirichlet_process',
    mean_precision_prior=0.01, covariance_prior=1e0 * np.eye(dim),
    init_params="random", max_iter=100, random_state=2).fit(X)

n_components = 2
cluster = []
for i in temp_table.iterrows():
    cluster.append(dpgmm.predict(i[1:])[0])
map = {}
for i, j in enumerate(set(cluster)):
    map[j] = i
for i in range(len(cluster)):
    cluster[i] = map[cluster[i]]
    
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=2)
Y = tsne.fit_transform(X)
Y = np.concatenate((Y, (np.array([cluster])).T), axis=1)
ax.scatter(Y[:, 0], Y[:, 1], c=Y[:, 2], alpha = 0.9)


var = '4:Num_Editor'
ax = axes[1]
ax.set_xlabel("t-SNE $N_p$")
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
#temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
#temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")
temp_table.columns = ["X1", "X2", "X3", "X4", "X5"][0:dim]
#X = np.log(np.array(temp_table))
X = (np.array(temp_table))
dpgmm = mixture.BayesianGaussianMixture(
    n_components=10, covariance_type='full', weight_concentration_prior=1,
    weight_concentration_prior_type='dirichlet_process',
    mean_precision_prior=0.01, covariance_prior=1e0 * np.eye(dim),
    init_params="random", max_iter=100, random_state=2).fit(X)

n_components = 2
cluster = []
for i in temp_table.iterrows():
    cluster.append(dpgmm.predict(i[1:])[0])
map = {}
for i, j in enumerate(set(cluster)):
    map[j] = i
for i in range(len(cluster)):
    cluster[i] = map[cluster[i]]
    
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=2)
Y = tsne.fit_transform(X)
Y = np.concatenate((Y, (np.array([cluster])).T), axis=1)
ax.scatter(Y[:, 0], Y[:, 1], c=Y[:, 2], alpha = 0.9)

var = '6:Num_Article'
ax = axes[2]
ax.set_xlabel("t-SNE $N_a$")
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
#temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
#temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")
temp_table.columns = ["X1", "X2", "X3", "X4", "X5"][0:dim]
#X = np.log(np.array(temp_table))
X = (np.array(temp_table))
dpgmm = mixture.BayesianGaussianMixture(
    n_components=10, covariance_type='full', weight_concentration_prior=1,
    weight_concentration_prior_type='dirichlet_process',
    mean_precision_prior=0.01, covariance_prior=1e0 * np.eye(dim),
    init_params="random", max_iter=100, random_state=2).fit(X)

n_components = 2
cluster = []
for i in temp_table.iterrows():
    cluster.append(dpgmm.predict(i[1:])[0])
map = {}
for i, j in enumerate(set(cluster)):
    map[j] = i
for i in range(len(cluster)):
    cluster[i] = map[cluster[i]]
    
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=5)
Y = tsne.fit_transform(X)
Y = np.concatenate((Y, (np.array([cluster])).T), axis=1)
ax.scatter(Y[:, 0], Y[:, 1], c=Y[:, 2], alpha = 0.9)

index = 0
labellist = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j", "k", "l", "m"]
for ax in fig.get_axes():
    ax.get_yaxis().set_label_coords(-0.1,0.5)
    ax.yaxis.label.set_fontsize(14)
    ax.tick_params(axis='x', labelsize=14)
    ax.text(0.1, 0.9, labellist[index], fontsize=14, weight='bold', transform=ax.transAxes) 
    index += 1

plt.tight_layout()
plt.savefig('SUP_FIG_010.pdf')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

var = '3:Num_Edit'
ax = axes[0]
ax.set_xlabel("t-SNE $N_e$")
dim = 5
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")
temp_table.columns = ["X1", "X2", "X3", "X4", "X5"][0:dim]
#X = np.log(np.array(temp_table))
X = (np.array(temp_table))
dpgmm = mixture.BayesianGaussianMixture(
    n_components=10, covariance_type='full', weight_concentration_prior=1e-2,
    weight_concentration_prior_type='dirichlet_process',
    mean_precision_prior=0.01, covariance_prior=1e0 * np.eye(dim),
    init_params="random", max_iter=100, random_state=2).fit(X)

n_components = 2
cluster = []
for i in temp_table.iterrows():
    cluster.append(dpgmm.predict(i[1:])[0])
map = {}
for i, j in enumerate(set(cluster)):
    map[j] = i
for i in range(len(cluster)):
    cluster[i] = map[cluster[i]]
    
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=2)
Y = tsne.fit_transform(X)
Y = np.concatenate((Y, (np.array([cluster])).T), axis=1)
ax.scatter(Y[:, 0], Y[:, 1], c=Y[:, 2], alpha = 0.9)


var = '4:Num_Editor'
ax = axes[1]
ax.set_xlabel("t-SNE $N_p$")
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")
temp_table.columns = ["X1", "X2", "X3", "X4", "X5"][0:dim]
#X = np.log(np.array(temp_table))
X = (np.array(temp_table))
dpgmm = mixture.BayesianGaussianMixture(
    n_components=10, covariance_type='full', weight_concentration_prior=1,
    weight_concentration_prior_type='dirichlet_process',
    mean_precision_prior=0.01, covariance_prior=1e0 * np.eye(dim),
    init_params="random", max_iter=100, random_state=2).fit(X)

n_components = 2
cluster = []
for i in temp_table.iterrows():
    cluster.append(dpgmm.predict(i[1:])[0])
map = {}
for i, j in enumerate(set(cluster)):
    map[j] = i
for i in range(len(cluster)):
    cluster[i] = map[cluster[i]]
    
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=2)
Y = tsne.fit_transform(X)
Y = np.concatenate((Y, (np.array([cluster])).T), axis=1)
ax.scatter(Y[:, 0], Y[:, 1], c=Y[:, 2], alpha = 0.9)

var = '6:Num_Article'
ax = axes[2]
ax.set_xlabel("t-SNE $N_a$")
temp_table_x = final_table[:][(final_table["type"] == "wiki") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_y = final_table[:][(final_table["type"] == "wiktionary") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_z = final_table[:][(final_table["type"] == "wikibooks") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h = final_table[:][(final_table["type"] == "wikiquote") & (final_table["lang_name"] != "")][['lang_code', var]]
temp_table_h1 = final_table[:][(final_table["type"] == "wikisource") & (final_table["lang_name"] != "")][['lang_code', var]]

temp_table = temp_table_x.merge(temp_table_y, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_z, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h, on="lang_code", how="inner")
temp_table = temp_table.merge(temp_table_h1, on="lang_code", how="inner")
temp_table = temp_table.set_index("lang_code")
temp_table.columns = ["X1", "X2", "X3", "X4", "X5"][0:dim]
#X = np.log(np.array(temp_table))
X = (np.array(temp_table))
dpgmm = mixture.BayesianGaussianMixture(
    n_components=10, covariance_type='full', weight_concentration_prior=1,
    weight_concentration_prior_type='dirichlet_process',
    mean_precision_prior=0.01, covariance_prior=1e0 * np.eye(dim),
    init_params="random", max_iter=100, random_state=2).fit(X)

n_components = 2
cluster = []
for i in temp_table.iterrows():
    cluster.append(dpgmm.predict(i[1:])[0])
map = {}
for i, j in enumerate(set(cluster)):
    map[j] = i
for i in range(len(cluster)):
    cluster[i] = map[cluster[i]]
    
tsne = manifold.TSNE(n_components=n_components, init='random', random_state=5)
Y = tsne.fit_transform(X)
Y = np.concatenate((Y, (np.array([cluster])).T), axis=1)
ax.scatter(Y[:, 0], Y[:, 1], c=Y[:, 2], alpha = 0.9)

index = 0
labellist = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j", "k", "l", "m"]
for ax in fig.get_axes():
    ax.get_yaxis().set_label_coords(-0.1,0.5)
    ax.yaxis.label.set_fontsize(14)
    ax.tick_params(axis='x', labelsize=14)
    ax.text(0.05, 0.95, labellist[index], fontsize=14, weight='bold', transform=ax.transAxes)  
    index += 1

plt.tight_layout()
plt.savefig('SUP_FIG_011.pdf')
plt.show()
