# %%
# %matplotlib inline  
import glob
import zipfile
import numpy as np
import gc
#from collections import defaultdict
import csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
#import powerlaw

# %%
final_table = pd.read_csv("./data/Allwiki_output_modify_langinfo.txt", sep=",")

# %%
types = ['wiki', 'wiktionary', 'wikibooks', 'wikiquote', 'wikisource', 'wikinews', 'wikivoyage', 'wikiversity']
types_index = [1,2,3,4,5,6,7,8,9]
types_name = ["All", 'Wikipedia', 'Wiktionary', 'Wikibooks', 'Wikiquote', 'Wikisource', 'Wikinews', 'Wikivoyage', 'Wikiversity']
types_map = {'wiki':'Wikipedia',
             'wiktionary':'Wiktionary',
             'wikibooks':'Wikibooks', 
             'wikiquote':'Wikiquote',
             'wikisource':'Wikisource',
             'wikinews':'Wikinews', 
             'wikivoyage':'Wikivoyage',
             'wikiversity':'Wikiversity'}
types_map_index = {'all':1,
             'wiki':2,
             'wiktionary':3,
             'wikibooks':4, 
             'wikiquote':5,
             'wikisource':6,
             'wikinews':7, 
             'wikivoyage':8,
             'wikiversity':9,}

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15,10))
outfile = "./grpout_rev2/power_fit_info_ne_np.pdf"

graph = pd.DataFrame(columns=["slope", "intercept", "rvalue", "pvalue", "stderr", "rawrvalue"])
xindex = '3:Num_Edit'
yindex = '4:Num_Editor'
axes[0,0].text(0.02, 0.92, "$N_e$-$N_p$", fontsize=20, weight='bold', transform=axes[0,0].transAxes)

graph.set_value(1, "slope", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).slope)
graph.set_value(1, "intercept", np.exp(scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).intercept))
graph.set_value(1, "rvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).rvalue)
graph.set_value(1, "pvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).pvalue)
graph.set_value(1, "stderr", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).stderr)
graph.set_value(1, "rawrvalue", scipy.stats.pearsonr(final_table[xindex], final_table[yindex])[0])
for tp in types:
    temp_table = final_table[:][(final_table["type"] == tp) & (final_table["lang_name"] != "")]
    cur_type = types_map[tp] 
    cur_type_idx = types_map_index[tp] 
    graph.set_value(cur_type_idx, "slope", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).slope)
    graph.set_value(cur_type_idx, "intercept", np.exp(scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).intercept))
    graph.set_value(cur_type_idx, "rvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).rvalue)
    graph.set_value(cur_type_idx, "pvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).pvalue)    
    graph.set_value(cur_type_idx, "stderr", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).stderr)    
    graph.set_value(cur_type_idx, "rawrvalue", scipy.stats.pearsonr(temp_table[xindex], temp_table[yindex])[0])

#print graph
graph.index_name = "Type"
axes[0,0].set_xticks(types_index)
axes[0,0].set_title("Exponent")
axes[0,0].set_xticklabels(types_name, rotation=40)
axes[0,0].scatter(types_index, graph.slope)

axes[0,1].scatter(types_index, graph.pvalue)
axes[0,1].set_title("p-value")
axes[0,1].set_ylim(0, 5e-07)
axes[0,1].set_xticks(types_index)
axes[0,1].set_xticklabels(types_name, rotation=40)

axes[0,2].scatter(types_index, graph.stderr)
axes[0,2].set_title("Standard error")
axes[0,2].set_xticks(types_index)
axes[0,2].set_xticklabels(types_name, rotation=40)

axes[1,0].scatter(types_index, graph.intercept)
axes[1,0].set_title("Proportionality coefficient")
axes[1,0].set_xticks(types_index)
axes[1,0].set_xticklabels(types_name, rotation=40)

axes[1,1].scatter(types_index, graph.rawrvalue)
axes[1,1].set_title("Pearson correlation r")
axes[1,1].set_xticks(types_index)
axes[1,1].set_xticklabels(types_name, rotation=40)

axes[1,2].scatter(types_index, graph.rvalue)
axes[1,2].set_title("Pearson correlation r (log-log)")
axes[1,2].set_xticks(types_index)
axes[1,2].set_xticklabels(types_name, rotation=40)


plt.tight_layout()
plt.savefig(outfile)
plt.show()

print graph
# Out:
#       slope  intercept    rvalue        pvalue     stderr rawrvalue
# 1  0.704249   0.738648  0.908861             0  0.0110146  0.895056
# 2  0.842443   0.155088  0.924524  8.82114e-138  0.0192937  0.895667
# 3  0.539973     1.8306  0.899576   4.71539e-63  0.0201075  0.871989
# 4   0.80007   0.593431  0.980026   2.51868e-85  0.0148827  0.993453
# 5  0.800656   0.552054  0.957503   9.37261e-49  0.0258568  0.976789
# 6  0.629638    1.27847  0.893163    1.5281e-23  0.0399435  0.926182
# 7  0.622501    1.11661  0.797903     2.683e-08   0.084464  0.773823
# 8   1.07859  0.0177923  0.925912   9.85812e-08   0.113614  0.979092
# 9  0.971437  0.0687041  0.944534   3.73727e-08  0.0902719  0.989328

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15,10))
outfile = "./grpout_rev2/power_fit_info_ne_na.pdf"

graph = pd.DataFrame(columns=["slope", "intercept", "rvalue", "pvalue", "stderr", "rawrvalue"])
xindex = '3:Num_Edit'
yindex = '6:Num_Article'
axes[0,0].text(0.02, 0.92, "$N_e$-$N_a$", fontsize=20, weight='bold', transform=axes[0,0].transAxes)

graph.set_value(1, "slope", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).slope)
graph.set_value(1, "intercept", np.exp(scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).intercept))
graph.set_value(1, "rvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).rvalue)
graph.set_value(1, "pvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).pvalue)
graph.set_value(1, "stderr", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).stderr)
graph.set_value(1, "rawrvalue", scipy.stats.pearsonr(final_table[xindex], final_table[yindex])[0])
for tp in types:
    temp_table = final_table[:][(final_table["type"] == tp) & (final_table["lang_name"] != "")]
    cur_type = types_map[tp] 
    cur_type_idx = types_map_index[tp] 
    graph.set_value(cur_type_idx, "slope", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).slope)
    graph.set_value(cur_type_idx, "intercept", np.exp(scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).intercept))
    graph.set_value(cur_type_idx, "rvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).rvalue)
    graph.set_value(cur_type_idx, "pvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).pvalue)    
    graph.set_value(cur_type_idx, "stderr", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).stderr)    
    graph.set_value(cur_type_idx, "rawrvalue", scipy.stats.pearsonr(temp_table[xindex], temp_table[yindex])[0])

#print graph
graph.index_name = "Type"
axes[0,0].set_xticks(types_index)
axes[0,0].set_title("Exponent")
axes[0,0].set_xticklabels(types_name, rotation=40)
axes[0,0].scatter(types_index, graph.slope)

axes[0,1].scatter(types_index, graph.pvalue)
axes[0,1].set_title("p-value")
axes[0,1].set_ylim(0, 5e-07)
axes[0,1].set_xticks(types_index)
axes[0,1].set_xticklabels(types_name, rotation=40)

axes[0,2].scatter(types_index, graph.stderr)
axes[0,2].set_title("Standard error")
axes[0,2].set_xticks(types_index)
axes[0,2].set_xticklabels(types_name, rotation=40)

axes[1,0].scatter(types_index, graph.intercept)
axes[1,0].set_title("Proportionality coefficient")
axes[1,0].set_xticks(types_index)
axes[1,0].set_xticklabels(types_name, rotation=40)

axes[1,1].scatter(types_index, graph.rawrvalue)
axes[1,1].set_title("Pearson correlation r")
axes[1,1].set_xticks(types_index)
axes[1,1].set_xticklabels(types_name, rotation=40)

axes[1,2].scatter(types_index, graph.rvalue)
axes[1,2].set_title("Pearson correlation r (log-log)")
axes[1,2].set_xticks(types_index)
axes[1,2].set_xticklabels(types_name, rotation=40)


plt.tight_layout()
plt.savefig(outfile)
plt.show()

print graph
# Out:
#       slope intercept    rvalue        pvalue      stderr rawrvalue
# 1  0.851328  0.953075  0.976546             0  0.00639681  0.851105
# 2  0.937205  0.256999  0.976168  4.77656e-217   0.0115751  0.849992
# 3  0.886418  0.876804  0.985567  4.55051e-133   0.0116775  0.971678
# 4  0.793356   1.77387  0.990358  5.16281e-104   0.0101733  0.979341
# 5  0.769828   1.93982  0.989899   1.33307e-75   0.0118208  0.949461
# 6   0.97134  0.472484  0.986329   4.70482e-51   0.0204457  0.980636
# 7  0.780295   1.99977  0.912861   1.34633e-13   0.0626789  0.789431
# 8  0.809312  0.853837  0.970794   1.04428e-10   0.0516414  0.982997
# 9  0.928145  0.316529  0.960594   3.56437e-09   0.0717772  0.984704

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15,10))
outfile = "./grpout_rev2/power_fit_info_ne_s.pdf"

graph = pd.DataFrame(columns=["slope", "intercept", "rvalue", "pvalue", "stderr", "rawrvalue"])
xindex = '3:Num_Edit'
yindex = '7:Wiki_Size'
axes[0,0].text(0.02, 0.92, "$N_e$-$S$", fontsize=20, weight='bold', transform=axes[0,0].transAxes)

graph.set_value(1, "slope", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).slope)
graph.set_value(1, "intercept", np.exp(scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).intercept))
graph.set_value(1, "rvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).rvalue)
graph.set_value(1, "pvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).pvalue)
graph.set_value(1, "stderr", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).stderr)
graph.set_value(1, "rawrvalue", scipy.stats.pearsonr(final_table[xindex], final_table[yindex])[0])
for tp in types:
    temp_table = final_table[:][(final_table["type"] == tp) & (final_table["lang_name"] != "")]
    cur_type = types_map[tp] 
    cur_type_idx = types_map_index[tp] 
    graph.set_value(cur_type_idx, "slope", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).slope)
    graph.set_value(cur_type_idx, "intercept", np.exp(scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).intercept))
    graph.set_value(cur_type_idx, "rvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).rvalue)
    graph.set_value(cur_type_idx, "pvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).pvalue)    
    graph.set_value(cur_type_idx, "stderr", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).stderr)    
    graph.set_value(cur_type_idx, "rawrvalue", scipy.stats.pearsonr(temp_table[xindex], temp_table[yindex])[0])

#print graph
graph.index_name = "Type"
axes[0,0].set_xticks(types_index)
axes[0,0].set_title("Exponent")
axes[0,0].set_xticklabels(types_name, rotation=40)
axes[0,0].scatter(types_index, graph.slope)

axes[0,1].scatter(types_index, graph.pvalue)
axes[0,1].set_title("p-value")
axes[0,1].set_ylim(0, 5e-07)
axes[0,1].set_xticks(types_index)
axes[0,1].set_xticklabels(types_name, rotation=40)

axes[0,2].scatter(types_index, graph.stderr)
axes[0,2].set_title("Standard error")
axes[0,2].set_xticks(types_index)
axes[0,2].set_xticklabels(types_name, rotation=40)

axes[1,0].scatter(types_index, graph.intercept)
axes[1,0].set_title("Proportionality coefficient")
axes[1,0].set_xticks(types_index)
axes[1,0].set_xticklabels(types_name, rotation=40)

axes[1,1].scatter(types_index, graph.rawrvalue)
axes[1,1].set_title("Pearson correlation r")
axes[1,1].set_xticks(types_index)
axes[1,1].set_xticklabels(types_name, rotation=40)

axes[1,2].scatter(types_index, graph.rvalue)
axes[1,2].set_title("Pearson correlation r (log-log)")
axes[1,2].set_xticks(types_index)
axes[1,2].set_xticklabels(types_name, rotation=40)


plt.tight_layout()
plt.savefig(outfile)
plt.show()

print graph
# Out:
#       slope intercept    rvalue        pvalue     stderr rawrvalue
# 1  0.874691    1060.2  0.945977             0  0.0102172  0.945518
# 2  0.987816   194.482  0.962968  1.67783e-186  0.0153652  0.946319
# 3  0.802352   1652.41  0.967582  1.59106e-103  0.0160625  0.892158
# 4  0.976815   728.319  0.947805   6.49852e-61  0.0301235  0.966832
# 5  0.891003   830.313  0.973655   1.22181e-57  0.0223718  0.977249
# 6  0.989188   1610.76  0.951021   7.94853e-34  0.0405094   0.95127
# 7  0.814366   1697.14  0.911193   1.78508e-13   0.066131  0.955948
# 8   0.84615   1612.54  0.912402    3.3267e-07  0.0980059  0.956239
# 9  0.894525   1310.47  0.952962     1.206e-08  0.0760369  0.981032

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15,10))
outfile = "./grpout_rev2/power_fit_info_na_np.pdf"

graph = pd.DataFrame(columns=["slope", "intercept", "rvalue", "pvalue", "stderr", "rawrvalue"])
xindex = '6:Num_Article'
yindex = '4:Num_Editor'
axes[0,0].text(0.02, 0.92, "$N_a$-$N_p$", fontsize=20, weight='bold', transform=axes[0,0].transAxes)

graph.set_value(1, "slope", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).slope)
graph.set_value(1, "intercept", np.exp(scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).intercept))
graph.set_value(1, "rvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).rvalue)
graph.set_value(1, "pvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).pvalue)
graph.set_value(1, "stderr", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).stderr)
graph.set_value(1, "rawrvalue", scipy.stats.pearsonr(final_table[xindex], final_table[yindex])[0])
for tp in types:
    temp_table = final_table[:][(final_table["type"] == tp) & (final_table["lang_name"] != "")]
    cur_type = types_map[tp] 
    cur_type_idx = types_map_index[tp] 
    graph.set_value(cur_type_idx, "slope", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).slope)
    graph.set_value(cur_type_idx, "intercept", np.exp(scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).intercept))
    graph.set_value(cur_type_idx, "rvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).rvalue)
    graph.set_value(cur_type_idx, "pvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).pvalue)    
    graph.set_value(cur_type_idx, "stderr", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).stderr)    
    graph.set_value(cur_type_idx, "rawrvalue", scipy.stats.pearsonr(temp_table[xindex], temp_table[yindex])[0])

#print graph
graph.index_name = "Type"
axes[0,0].set_xticks(types_index)
axes[0,0].set_title("Exponent")
axes[0,0].set_xticklabels(types_name, rotation=40)
axes[0,0].scatter(types_index, graph.slope)

axes[0,1].scatter(types_index, graph.pvalue)
axes[0,1].set_title("p-value")
axes[0,1].set_ylim(0, 2e-05)
axes[0,1].set_xticks(types_index)
axes[0,1].set_xticklabels(types_name, rotation=40)

axes[0,2].scatter(types_index, graph.stderr)
axes[0,2].set_title("Standard error")
axes[0,2].set_xticks(types_index)
axes[0,2].set_xticklabels(types_name, rotation=40)

axes[1,0].scatter(types_index, graph.intercept)
axes[1,0].set_title("Proportionality coefficient")
axes[1,0].set_xticks(types_index)
axes[1,0].set_xticklabels(types_name, rotation=40)

axes[1,1].scatter(types_index, graph.rawrvalue)
axes[1,1].set_title("Pearson correlation r")
axes[1,1].set_xticks(types_index)
axes[1,1].set_xticklabels(types_name, rotation=40)

axes[1,2].scatter(types_index, graph.rvalue)
axes[1,2].set_title("Pearson correlation r (log-log)")
axes[1,2].set_xticks(types_index)
axes[1,2].set_xticklabels(types_name, rotation=40)


plt.tight_layout()
plt.savefig(outfile)
plt.show()

print graph
# Out:
#       slope  intercept    rvalue        pvalue     stderr rawrvalue
# 1  0.778094    1.19935  0.875402  4.75127e-274  0.0146429  0.649975
# 2  0.855545   0.817538  0.901426  7.78944e-120  0.0228277     0.651
# 3  0.585252    2.47369  0.876922   5.63334e-56  0.0246021  0.773866
# 4  0.980838   0.403144  0.962462   3.03686e-69  0.0253558  0.956404
# 5   1.01275   0.338911  0.941891   5.47922e-43  0.0387238  0.878766
# 6  0.616042     2.8482  0.860595    4.0016e-20   0.045931  0.884531
# 7  0.797727   0.642675  0.874015   3.09171e-11  0.0796528  0.955328
# 8   1.18817  0.0829023  0.850316   1.53426e-05   0.189872  0.929965
# 9  0.940047   0.609241  0.883137   5.82933e-06   0.133455  0.966194

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15,10))
outfile = "./grpout_rev2/power_fit_info_na_s.pdf"

graph = pd.DataFrame(columns=["slope", "intercept", "rvalue", "pvalue", "stderr", "rawrvalue"])
xindex = '6:Num_Article'
yindex = '7:Wiki_Size'
axes[0,0].text(0.02, 0.92, "$N_a$-$S$", fontsize=20, weight='bold', transform=axes[0,0].transAxes)

graph.set_value(1, "slope", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).slope)
graph.set_value(1, "intercept", np.exp(scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).intercept))
graph.set_value(1, "rvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).rvalue)
graph.set_value(1, "pvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).pvalue)
graph.set_value(1, "stderr", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).stderr)
graph.set_value(1, "rawrvalue", scipy.stats.pearsonr(final_table[xindex], final_table[yindex])[0])
for tp in types:
    temp_table = final_table[:][(final_table["type"] == tp) & (final_table["lang_name"] != "")]
    cur_type = types_map[tp] 
    cur_type_idx = types_map_index[tp] 
    graph.set_value(cur_type_idx, "slope", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).slope)
    graph.set_value(cur_type_idx, "intercept", np.exp(scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).intercept))
    graph.set_value(cur_type_idx, "rvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).rvalue)
    graph.set_value(cur_type_idx, "pvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).pvalue)    
    graph.set_value(cur_type_idx, "stderr", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).stderr)    
    graph.set_value(cur_type_idx, "rawrvalue", scipy.stats.pearsonr(temp_table[xindex], temp_table[yindex])[0])

#print graph
graph.index_name = "Type"
axes[0,0].set_xticks(types_index)
axes[0,0].set_title("Exponent")
axes[0,0].set_xticklabels(types_name, rotation=40)
axes[0,0].scatter(types_index, graph.slope)

axes[0,1].scatter(types_index, graph.pvalue)
axes[0,1].set_title("p-value")
axes[0,1].set_ylim(0, 5e-07)
axes[0,1].set_xticks(types_index)
axes[0,1].set_xticklabels(types_name, rotation=40)

axes[0,2].scatter(types_index, graph.stderr)
axes[0,2].set_title("Standard error")
axes[0,2].set_xticks(types_index)
axes[0,2].set_xticklabels(types_name, rotation=40)

axes[1,0].scatter(types_index, graph.intercept)
axes[1,0].set_title("Proportionality coefficient")
axes[1,0].set_xticks(types_index)
axes[1,0].set_xticklabels(types_name, rotation=40)

axes[1,1].scatter(types_index, graph.rawrvalue)
axes[1,1].set_title("Pearson correlation r")
axes[1,1].set_xticks(types_index)
axes[1,1].set_xticklabels(types_name, rotation=40)

axes[1,2].scatter(types_index, graph.rvalue)
axes[1,2].set_title("Pearson correlation r (log-log)")
axes[1,2].set_xticks(types_index)
axes[1,2].set_xticklabels(types_name, rotation=40)


plt.tight_layout()
plt.savefig(outfile)
plt.show()

print graph
# Out:
#       slope intercept    rvalue        pvalue      stderr rawrvalue
# 1   1.02171   1173.25  0.963288             0  0.00970426  0.837651
# 2   1.05038   844.892   0.98309  6.05665e-241   0.0108699  0.838299
# 3  0.900004    1952.1  0.976157  1.03859e-114   0.0153493  0.916696
# 4   1.23187   358.065  0.957518   4.13478e-66   0.0340094  0.958276
# 5   1.15488   392.896  0.981443    3.4505e-64   0.0241913  0.938157
# 6  0.999274   4167.22  0.946118   1.48979e-32   0.0430899  0.944978
# 7  0.981187   1486.77  0.938418   7.42196e-16   0.0648819  0.910617
# 8   1.02266   2346.81  0.919303   1.83492e-07    0.113038  0.970173
# 9  0.944827   4725.61  0.972548   2.92993e-10   0.0604193  0.980323

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15,10))
outfile = "./grpout_rev2/power_fit_info_np_s.pdf"

graph = pd.DataFrame(columns=["slope", "intercept", "rvalue", "pvalue", "stderr", "rawrvalue"])
xindex = '4:Num_Editor'
yindex = '7:Wiki_Size'
axes[0,0].text(0.02, 0.92, "$N_p$-$S$", fontsize=20, weight='bold', transform=axes[0,0].transAxes)

graph.set_value(1, "slope", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).slope)
graph.set_value(1, "intercept", np.exp(scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).intercept))
graph.set_value(1, "rvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).rvalue)
graph.set_value(1, "pvalue", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).pvalue)
graph.set_value(1, "stderr", scipy.stats.linregress(np.log(final_table[xindex]), np.log(final_table[yindex])).stderr)
graph.set_value(1, "rawrvalue", scipy.stats.pearsonr(final_table[xindex], final_table[yindex])[0])
for tp in types:
    temp_table = final_table[:][(final_table["type"] == tp) & (final_table["lang_name"] != "")]
    cur_type = types_map[tp] 
    cur_type_idx = types_map_index[tp] 
    graph.set_value(cur_type_idx, "slope", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).slope)
    graph.set_value(cur_type_idx, "intercept", np.exp(scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).intercept))
    graph.set_value(cur_type_idx, "rvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).rvalue)
    graph.set_value(cur_type_idx, "pvalue", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).pvalue)    
    graph.set_value(cur_type_idx, "stderr", scipy.stats.linregress(np.log(temp_table[xindex]), np.log(temp_table[yindex])).stderr)    
    graph.set_value(cur_type_idx, "rawrvalue", scipy.stats.pearsonr(temp_table[xindex], temp_table[yindex])[0])

#print graph
graph.index_name = "Type"
axes[0,0].set_xticks(types_index)
axes[0,0].set_title("Exponent")
axes[0,0].set_xticklabels(types_name, rotation=40)
axes[0,0].scatter(types_index, graph.slope)

axes[0,1].scatter(types_index, graph.pvalue)
axes[0,1].set_title("p-value")
axes[0,1].set_ylim(0, 1e-03)
axes[0,1].set_xticks(types_index)
axes[0,1].set_xticklabels(types_name, rotation=40)

axes[0,2].scatter(types_index, graph.stderr)
axes[0,2].set_title("Standard error")
axes[0,2].set_xticks(types_index)
axes[0,2].set_xticklabels(types_name, rotation=40)

axes[1,0].scatter(types_index, graph.intercept)
axes[1,0].set_title("Proportionality coefficient")
axes[1,0].set_xticks(types_index)
axes[1,0].set_xticklabels(types_name, rotation=40)

axes[1,1].scatter(types_index, graph.rawrvalue)
axes[1,1].set_title("Pearson correlation r")
axes[1,1].set_xticks(types_index)
axes[1,1].set_xticklabels(types_name, rotation=40)

axes[1,2].scatter(types_index, graph.rvalue)
axes[1,2].set_title("Pearson correlation r (log-log)")
axes[1,2].set_xticks(types_index)
axes[1,2].set_xticklabels(types_name, rotation=40)


plt.tight_layout()
plt.savefig(outfile)
plt.show()

print graph
# Out:
#       slope intercept    rvalue        pvalue     stderr rawrvalue
# 1   1.05915   5791.23  0.887589  4.34038e-292  0.0187328  0.726656
# 2   1.02253   6194.46  0.908313  1.11367e-124  0.0261606  0.725107
# 3   1.22303   3538.51  0.885312   2.01837e-58  0.0492685   0.74788
# 4   1.16045   1966.04  0.919231   5.32294e-50  0.0455632  0.965096
# 5   1.02918   2743.78  0.940423   1.57166e-42   0.039893  0.967549
# 6   1.30461   7218.73  0.884204   1.67893e-22  0.0868298  0.927855
# 7  0.968762   16377.6  0.845663   5.84945e-10   0.109812  0.896203
# 8  0.593184    190739  0.745099   0.000598694   0.137096  0.906938
# 9  0.809554   38139.5  0.887005   4.65512e-06   0.112635  0.978002

# %%
plt.close()
